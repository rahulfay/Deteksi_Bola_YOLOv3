# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/yolo-tinyv3'
# Out:
#  backup				  data2
#  bad_label.list			  data3
#  bad.list			  data4
#  bola.zip			 'databola(mayan bagus)'
#  chart.png			  data_robot
#  chart_yolov3-tiny-customm.png	 'datarobot(jelek5%)'
#  chart_yolov3-tiny-custommz.png  'gambar robot.zip'
#  chart_yolov3-tiny-custom.png	  images_ball.zip
#  chart_yolov4-tiny-custom1.png	  omni.zip
#  custom_weight			  Rename_files.ipynb
#  darknet			  robot.zip

# %%
# !unzip '/content/drive/My Drive/yolo-tinyv3/robot.zip' -d '/content/drive/My Drive/yolo-tinyv3/'
# Out:
# Archive:  /content/drive/My Drive/yolo-tinyv3/robot.zip
#    creating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/1.jpeg
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/1.txt
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/10.jpeg
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/10.txt
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/100.jpeg
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/100.txt
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/101.jpeg
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/101.txt
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/102.jpeg
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/102.txt
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/103.jpeg
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/103.txt
#   inflating: /content/drive/My Drive/yolo-tinyv3/ROBOT2/104.jpeg
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet' '/content/drive/My Drive/yolo-tinyv3/darknet'

# %%
#!wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# %cd /content/drive/My Drive/yolo-tinyv3/darknet
# Out:
# /content/drive/My Drive/yolo-tinyv3/darknet

# %%
makefiletemp = open('Makefile','r+') 
list_of_lines = makefiletemp.readlines()
list_of_lines[15] = list_of_lines[14]
list_of_lines[16] = "ARCH= -gencode arch=compute_35,code=sm_35 \\\n"

makefiletemp = open('Makefile','w')
makefiletemp.writelines(list_of_lines)
makefiletemp.close()

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd /content/drive/My Drive/yolo-tinyv3/
# Out:
# /content/drive/My Drive/yolo-tinyv3

# %%
# !ls
# Out:
#  backup				  data2
#  bad_label.list			  data3
#  bad.list			  data4
#  bola.zip			 'databola(mayan bagus)'
#  chart.png			  data_robot
#  chart_yolov3-tiny-customm.png	 'datarobot(jelek5%)'
#  chart_yolov3-tiny-custommz.png  'gambar robot.zip'
#  chart_yolov3-tiny-custom.png	  images_ball.zip
#  chart_yolov4-tiny-custom1.png	  omni.zip
#  custom_weight			  Rename_files.ipynb
#  darknet			  robot.zip
#  data

# %%
# !python data/creating-files-data-and-name.py

# %%
# !python data/creating-train-and-test-txt-files.py

# %%
# !chmod +x ./darknet/darknet

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train data/labelled_data.data darknet/cfg/yolov3-tiny-customm.cfg custom_weight/darknet53.conv.74 -dont_show -map -clear
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  (next mAP calculation at 2500 iterations)
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
#  Last accuracy mAP@0.50 = 96.75 %, best = 97.60 %
#  2425: 0.142661, 0.154625 avg loss, 0.005000 rate, 0.359124 seconds, 77600 images, 1.518498 hours left
# Loaded: 1.007040 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.797902), count: 2, class_loss = 0.005838, iou_loss = 0.048973, total_loss = 0.054811
#  total_bbox = 71612, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.000000), count: 1, class_loss = 0.000182, iou_loss = 0.000000, total_loss = 0.000182
# ...
